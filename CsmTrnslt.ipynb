# %% [markdown]
# <a href="https://colab.research.google.com/github/Andron00e/Fine-Tuning-project/blob/main/CsmTrnslt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/huggingface/peft.git git+https://github.com/huggingface/transformers.git
# !pip install accelerate
# !pip install bitsandbytes
# !pip install sentencepiece
# !pip install datasets
# !pip uninstall wandb
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.40.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# WARNING: Skipping wandb as it is not installed.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.empty_cache()

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import torch.nn as nn
import bitsandbytes as bnb
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("openlm-research/open_llama_3b")
tokenizer.pad_token_id = (
    0  # unk. we want this to be different from the eos token
)
tokenizer.padding_side = "left"
tokenizer
# Out:
# LlamaTokenizerFast(name_or_path='openlm-research/open_llama_3b', vocab_size=32000, model_max_length=2048, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'pad_token': '<unk>'}, clean_up_tokenization_spaces=False)

# %%
model = AutoModelForCausalLM.from_pretrained(
    "openlm-research/open_llama_3b",
    torch_dtype=torch.float16,
    load_in_8bit=True,
    device_map='auto',
)
print(model)
# Out:
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 3200, padding_idx=0)
#     (layers): ModuleList(
#       (0-25): 26 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear8bitLt(in_features=3200, out_features=3200, bias=False)
#           (k_proj): Linear8bitLt(in_features=3200, out_features=3200, bias=False)
#           (v_proj): Linear8bitLt(in_features=3200, out_features=3200, bias=False)
#           (o_proj): Linear8bitLt(in_features=3200, out_features=3200, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear8bitLt(in_features=3200, out_features=8640, bias=False)
#           (up_proj): Linear8bitLt(in_features=3200, out_features=8640, bias=False)
#           (down_proj): Linear8bitLt(in_features=8640, out_features=3200, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=3200, out_features=32000, bias=False)
# )

# %%
for param in model.parameters():
  param.requires_grad = False  # freeze the model - train adapters later
  if param.ndim == 1:
    # cast the small parameters (e.g. layernorm) to fp32 for stability
    param.data = param.data.to(torch.float32)

model.gradient_checkpointing_enable()  # reduce number of stored activations
model.enable_input_require_grads()

class CastOutputToFloat(nn.Sequential):
  def forward(self, x): return super().forward(x).to(torch.float32)
model.lm_head = CastOutputToFloat(model.lm_head)

# %%
def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
from peft import LoraConfig, get_peft_model

config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=[
    "q_proj",
    "v_proj",
],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

model = get_peft_model(model, config)
print_trainable_parameters(model)
# Out:
# trainable params: 2662400 || all params: 3429136000 || trainable%: 0.07764054852300988

# %% [markdown]
# # My dataset

# %%
from datasets import load_dataset

train_dataset = load_dataset("csv", data_files="concatenated_trans.csv", split = "train")
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-0944c3b6d35127ec/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-0944c3b6d35127ec/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d. Subsequent calls will reuse this data.

# %%
train_dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'system_prompt', 'question', 'response', 'tr question', 'tr response'],
#     num_rows: 16891
# })

# %%
train_dataset = train_dataset.rename_column("tr question", "tr_question")

# %%
train_dataset = train_dataset.rename_column("tr response", "tr_response")

# %%
train_dataset = train_dataset.remove_columns("Unnamed: 0")

# %%
train_dataset
# Out:
# Dataset({
#     features: ['system_prompt', 'question', 'response', 'tr_question', 'tr_response'],
#     num_rows: 16891
# })

# %% [markdown]
# prompt

# %%
def create_prompt(system_prompt: str, question: str, response: str, tr_question: str, tr_response: str):
  if len(response) < 1:
    response = "Cannot Find Answer"
  else:
    response = response
  prompt_template = f"### CONTEXT\n{system_prompt}\n\n### QUESTION\n{question}\n\n### RESPONSE\n{response}\n\n### TRANSLATED QUESTION\n{tr_question}\n\n### TRANSLATED RESPONSE\n{tr_response}</s>"
  return prompt_template

# %%
def tokenize_function(samples):
  return tokenizer(create_prompt(samples['system_prompt'],
                                 samples['question'],
                                 samples['response'],
                                 samples['tr_question'],
                                 samples['tr_response']),
                                 padding='max_length',
                                 truncation=True
                   )



mapped_train_dataset = train_dataset.map(tokenize_function)
# Out:
# Map:   0%|          | 0/16891 [00:00<?, ? examples/s]

# %%
mapped_train_dataset
# Out:
# Dataset({
#     features: ['system_prompt', 'question', 'response', 'tr_question', 'tr_response', 'input_ids', 'attention_mask'],
#     num_rows: 16891
# })

# %% [markdown]
# # Dataset for translation

# %%
from datasets import inspect_dataset, load_dataset_builder, load_dataset

dataset = load_dataset("wmt19", 'ru-en')

'''
inspect_dataset("wmt19")
builder = load_dataset_builder(
    local_path = "/content",
    language_pair=("en", "ru"),
    split = "train"
    #subsets={
    #    datasets.Split.TRAIN: ["commoncrawl_frde"],
    #    datasets.Split.VALIDATION: ["euelections_dev2019"],
    #},
'''
# Out:
# Downloading and preparing dataset wmt19/ru-en to /root/.cache/huggingface/datasets/wmt19/ru-en/1.0.0/29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a...
# Downloading data files:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/668M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/919M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.45G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/38.7M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/6 [00:00<?, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split:   0%|          | 0/37492126 [00:00<?, ? examples/s]
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 19415 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 19419 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 19434 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 39894 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 39899 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 39900 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 39915 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 39920 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 39923 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 50815 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 50818 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 50820 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 50829 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 50831 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 52209 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 52210 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 52214 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 52220 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 52224 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 52226 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 73469 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 73494 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 75844 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 76410 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 76412 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 76416 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 76417 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 79373 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 79377 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 79390 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81046 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81051 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81052 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81054 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81058 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81063 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81754 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81758 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81759 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81761 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81763 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81774 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81781 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 81786 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 4 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 93910 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 93912 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 93930 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 94400 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 94403 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 94427 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 94429 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 102741 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 102748 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 102755 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 110708 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 124040 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 124057 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 124059 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 128721 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 128726 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 131020 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 131025 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 131030 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141106 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141108 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141111 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141113 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141116 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141118 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141120 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141128 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141132 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141136 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 141137 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 145070 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 145071 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 147604 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 147616 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 147618 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 149764 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 149774 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 149787 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 157494 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 157888 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 157907 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 157913 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 161073 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 161075 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 161082 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 161087 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 161089 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 161092 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173387 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173393 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173399 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173401 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173408 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173410 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 173421 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 177141 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 177146 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 177153 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 177159 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 192344 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 192352 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 192354 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 192356 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 192360 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 192361 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 205869 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 205870 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 205874 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 207474 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 207490 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 270477 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 270478 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 270496 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 270504 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 274370 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 274371 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 274373 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# WARNING:datasets_modules.datasets.wmt19.29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a.wmt_utils:Skipping line 274388 in TSV (/root/.cache/huggingface/datasets/downloads/extracted/7f5739f7e234cd46b873c999a898c40b3f56b4f6fee0ac46401810a706da2720) with 3 != 2 columns.
# Generating validation split:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Dataset wmt19 downloaded and prepared to /root/.cache/huggingface/datasets/wmt19/ru-en/1.0.0/29e210fae5690e843cae5dc43b53db36c4e02f927db50cd5235a22ab42dde90a. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# '\ninspect_dataset("wmt19")\nbuilder = load_dataset_builder(\n    local_path = "/content",\n    language_pair=("en", "ru"),\n    split = "train"\n    #subsets={\n    #    datasets.Split.TRAIN: ["commoncrawl_frde"],\n    #    datasets.Split.VALIDATION: ["euelections_dev2019"],\n    #},\n'

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 29993700
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 7498426
#     })
# })

# %%
dataset = dataset["train"].train_test_split(test_size=0.2)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 23994960
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 5998740
#     })
# })

# %%
dataset["train"][5]
# Out:
# {'translation': {'en': '1 long blast repeated at least once a minute',
#   'ru': '1 продолжительный звук, повторяющийся с интервалом не более одной минуты'}}

# %%
data = dataset["train"]
data
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 23994960
# })

# %%
sharded_dataset = data.shard(num_shards = 300, index=0)
sharded_dataset
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 79984
# })

# %%
sharded_dataset[5]
# Out:
# {'translation': {'en': '23 February 1991', 'ru': '23 февраля 1991 года'}}

# %%
dic = {'translation': {'en': '23 February 1991', 'ru': '23 февраля 1991 года'}}
dic['translation']['en']
# Out:
# '23 February 1991'

# %%
sharded_dataset[17]['translation']['en']
# Out:
# 'In fact, the very opposite is true; they have only served to harden attitudes of one community against the other.'

# %%
from tqdm import tqdm

input = []
for i in tqdm(range(len(sharded_dataset))):
  input.append(sharded_dataset[i]['translation']['en'])

output = []
for i in tqdm(range(len(sharded_dataset))):
  output.append(sharded_dataset[i]['translation']['ru'])

print(len(input), '\n')
print(len(output))
# Out:
# 100%|██████████| 79984/79984 [04:55<00:00, 270.52it/s]
# 100%|██████████| 79984/79984 [05:21<00:00, 248.97it/s]
# 79984
#
# 79984

# %%
sharded_dataset = sharded_dataset.add_column("input", input)
sharded_dataset
# Out:
# Flattening the indices:   0%|          | 0/79984 [00:00<?, ? examples/s]
# Dataset({
#     features: ['translation', 'input'],
#     num_rows: 79984
# })

# %%
sharded_dataset=sharded_dataset.remove_columns("translation")

# %%
sharded_dataset = sharded_dataset.add_column("output", output)
sharded_dataset
# Out:
# Dataset({
#     features: ['input', 'output'],
#     num_rows: 79984
# })

# %%
def create_prompt(input: str, output: str):
  if len(output) < 1:
    output = "Cannot Find Answer"
  else:
    output = output
  prompt_template = f"### INPUT\n{input}\n\n### OUTPUT\n{output}"
  return prompt_template

# %%
def tokenize_function(samples):
  return tokenizer(create_prompt(samples['input'], samples['output']), padding='max_length', truncation=True)



mapped_train_dataset = sharded_dataset.map(tokenize_function)
# Out:
# Map:   0%|          | 0/79984 [00:00<?, ? examples/s]

# %%
mapped_train_dataset
# Out:
# Dataset({
#     features: ['input', 'output', 'input_ids', 'attention_mask'],
#     num_rows: 79984
# })

# %% [markdown]
# # Training and stuff

# %%
import transformers

trainer = transformers.Trainer(
    model=model,
    train_dataset=mapped_train_dataset,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=16,
        warmup_steps=100,
        max_steps=100,
        learning_rate=1e-3,
        fp16=True,
        logging_steps=1,
        output_dir='outputs',
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = False

# %%
with torch.autocast("cuda"):
    trainer.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-916c116ca58b> in <cell line: 1>()
#       1 with torch.autocast("cuda"):
# ----> 2     trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1530             self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1531         )
# -> 1532         return inner_training_loop(
#    1533             args=args,
#    1534             resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1803
#    1804                 with self.accelerator.accumulate(model):
# -> 1805                     tr_loss_step = self.training_step(model, inputs)
#    1806
#    1807                 if (
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2646
#    2647         with self.compute_loss_context_manager():
# -> 2648             loss = self.compute_loss(model, inputs)
#    2649
#    2650         if self.args.n_gpu > 1:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    2671         else:
#    2672             labels = None
# -> 2673         outputs = model(**inputs)
#    2674         # Save past state if it exists
#    2675         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#     945                 )
#     946
# --> 947             return self.base_model(
#     948                 input_ids=input_ids,
#     949                 attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#     945                 )
#     946
# --> 947             return self.base_model(
#     948                 input_ids=input_ids,
#     949                 attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, *args, **kwargs)
#     435         Forward pass of the model.
#     436         """
# --> 437         return self.get_base_model()(*args, **kwargs)
#     438
#     439     def _get_base_model_class(self, is_prompt_tuning=False):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, *args, **kwargs)
#     435         Forward pass of the model.
#     436         """
# --> 437         return self.get_base_model()(*args, **kwargs)
#     438
#     439     def _get_base_model_class(self, is_prompt_tuning=False):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, decoder_input_ids, decoder_attention_mask, decoder_inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1103         peft_config = self.active_peft_config
#    1104         if not isinstance(peft_config, PromptLearningConfig):
# -> 1105             return self.base_model(
#    1106                 input_ids=input_ids,
#    1107                 attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(*args, **kwargs)
#     163                 output = old_forward(*args, **kwargs)
#     164         else:
# --> 165             output = old_forward(*args, **kwargs)
#     166         return module._hf_hook.post_forward(module, output)
#     167
#
# TypeError: LlamaForCausalLM.forward() got an unexpected keyword argument 'decoder_input_ids'

# %% [markdown]
# for CausalLM

# %%
import transformers

trainer = transformers.Trainer(
    model=model,
    train_dataset=mapped_train_dataset,
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=16,
        warmup_steps=100,
        max_steps=100,
        learning_rate=1e-3,
        fp16=True,
        logging_steps=1,
        output_dir='outputs',
    ),
    data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
)
model.config.use_cache = False  # silence the warnings. Please re-enable for inference!

# %%
with torch.autocast("cuda"):
    trainer.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-916c116ca58b> in <cell line: 1>()
#       1 with torch.autocast("cuda"):
# ----> 2     trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1530             self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1531         )
# -> 1532         return inner_training_loop(
#    1533             args=args,
#    1534             resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1803
#    1804                 with self.accelerator.accumulate(model):
# -> 1805                     tr_loss_step = self.training_step(model, inputs)
#    1806
#    1807                 if (
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2646
#    2647         with self.compute_loss_context_manager():
# -> 2648             loss = self.compute_loss(model, inputs)
#    2649
#    2650         if self.args.n_gpu > 1:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    2671         else:
#    2672             labels = None
# -> 2673         outputs = model(**inputs)
#    2674         # Save past state if it exists
#    2675         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#     945                 )
#     946
# --> 947             return self.base_model(
#     948                 input_ids=input_ids,
#     949                 attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, *args, **kwargs)
#     435         Forward pass of the model.
#     436         """
# --> 437         return self.get_base_model()(*args, **kwargs)
#     438
#     439     def _get_base_model_class(self, is_prompt_tuning=False):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, *args, **kwargs)
#     435         Forward pass of the model.
#     436         """
# --> 437         return self.get_base_model()(*args, **kwargs)
#     438
#     439     def _get_base_model_class(self, is_prompt_tuning=False):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     579
#     580     def forward(*args, **kwargs):
# --> 581         return model_forward(*args, **kwargs)
#     582
#     583     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     567
#     568     def __call__(self, *args, **kwargs):
# --> 569         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     570
#     571     def __getstate__(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      12     def decorate_autocast(*args, **kwargs):
#      13         with autocast_instance:
# ---> 14             return func(*args, **kwargs)
#      15     decorate_autocast.__script_unsupported = '@autocast() decorator is not supported in script mode'  # type: ignore[attr-defined]
#      16     return decorate_autocast
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, decoder_input_ids, decoder_attention_mask, decoder_inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1103         peft_config = self.active_peft_config
#    1104         if not isinstance(peft_config, PromptLearningConfig):
# -> 1105             return self.base_model(
#    1106                 input_ids=input_ids,
#    1107                 attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(*args, **kwargs)
#     163                 output = old_forward(*args, **kwargs)
#     164         else:
# --> 165             output = old_forward(*args, **kwargs)
#     166         return module._hf_hook.post_forward(module, output)
#     167
#
# TypeError: LlamaForCausalLM.forward() got an unexpected keyword argument 'decoder_input_ids'

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
HUGGING_FACE_USER_NAME = "Andron00e"

# %%
adapter_name = "YetAnother_Open-Llama-3B-LoRA-adapter"

# %%
model.push_to_hub(f"{HUGGING_FACE_USER_NAME}/{adapter_name}", use_auth_token=True)
# Out:
# adapter_model.bin:   0%|          | 0.00/10.7M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Andron00e/YetAnother_Open-Llama-3B-LoRA-adapter/commit/eb414491f1ee1115875da39f77580738a32f592b', commit_message='Upload model', commit_description='', oid='eb414491f1ee1115875da39f77580738a32f592b', pr_url=None, pr_revision=None, pr_num=None)

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

peft_model_id = f"{HUGGING_FACE_USER_NAME}/{adapter_name}"
config = PeftConfig.from_pretrained(peft_model_id)
model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, return_dict=True, load_in_8bit=False, torch_dtype=torch.bfloat16, device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)


qa_model = PeftModel.from_pretrained(model, peft_model_id)

# %%
from IPython.display import display, Markdown

def make_inference(system_prompt, question):
  batch = tokenizer(f"### CONTEXT\n{system_prompt}\n\n### QUESTION\n{question}\n\n### RESPONSE\n\n### TRANSLATED RESPONSE\n", return_tensors='pt')

  #with torch.cuda.amp.autocast():
    #output_tokens = qa_model.generate(**batch, max_new_tokens=200)
  with torch.cuda.amp.autocast():
  batch = {k: v.to(qa_model.device) for k, v in batch.items()}
  output_tokens = qa_model.generate(**batch, max_new_tokens=200)

  display(Markdown((tokenizer.decode(output_tokens[0], skip_special_tokens=True))))

# %%
system_prompt = "Cheese is the best food."
question = "What is the best food?"

make_inference(system_prompt, question)

# %%
merged_model = qa_model.merge_and_unload()

# %%
merged_model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 3200, padding_idx=0)
#     (layers): ModuleList(
#       (0-25): 26 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=3200, out_features=3200, bias=False)
#           (k_proj): Linear(in_features=3200, out_features=3200, bias=False)
#           (v_proj): Linear(in_features=3200, out_features=3200, bias=False)
#           (o_proj): Linear(in_features=3200, out_features=3200, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=3200, out_features=8640, bias=False)
#           (up_proj): Linear(in_features=3200, out_features=8640, bias=False)
#           (down_proj): Linear(in_features=8640, out_features=3200, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=3200, out_features=32000, bias=False)
# )

# %%
tokenizer
# Out:
# LlamaTokenizerFast(name_or_path='openlm-research/open_llama_3b', vocab_size=32000, model_max_length=2048, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'eos_token': AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=True), 'unk_token': AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=True)}, clean_up_tokenization_spaces=False)

# %%
merged_model_name = "YetAnother_Open-Llama-3B-LoRA"

merged_model.push_to_hub(f"{HUGGING_FACE_USER_NAME}/{merged_model_name}", use_auth_token=True)
tokenizer.push_to_hub(f"{HUGGING_FACE_USER_NAME}/{merged_model_name}", use_auth_token=True)
# Out:
# pytorch_model.bin:   0%|          | 0.00/6.85G [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/534k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Andron00e/YetAnother_Open-Llama-3B-LoRA/commit/101108cebb8bdc8fa9e461c2d3758492da02b0cb', commit_message='Upload tokenizer', commit_description='', oid='101108cebb8bdc8fa9e461c2d3758492da02b0cb', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# evaluation

# %%
import torch

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Andron00e/YetAnother_Open-Llama-3B-LoRA")
model = AutoModelForCausalLM.from_pretrained("Andron00e/YetAnother_Open-Llama-3B-LoRA", load_in_8bit=True, torch_dtype=torch.bfloat16, device_map='auto')
# Out:
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
# !pip install safetensors
# Out:
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.3.1)

# %%
from safetensors import safe_open

tensors = {}
with safe_open("model.safetensors", framework="pt", device=0) as f:
    for k in f.keys():
        tensors[k] = f.get_tensor(k)

# %%
import torch
from safetensors.torch import save_file

tensors = {
    "embedding": torch.zeros((2, 2)),
    "attention": torch.zeros((2, 3))
}
save_file(tensors, "model.safetensors")

# %%
from safetensors.torch import load_file

model.safetensors = load_file("./model.safetensors")
model.safetensors
# Out:
# {'attention': tensor([[0., 0., 0.],
#          [0., 0., 0.]]),
#  'embedding': tensor([[0., 0.],
#          [0., 0.]])}

# %%
merged_model_name = "YetAnother_Open-Llama-3B-LoRA"
HUGGING_FACE_USER_NAME = "Andron00e"

model.safetensors.push_to_hub(f"{HUGGING_FACE_USER_NAME}/{merged_model_name}", use_auth_token=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-744a5f933e79> in <cell line: 4>()
#       2 HUGGING_FACE_USER_NAME = "Andron00e"
#       3
# ----> 4 loaded.push_to_hub(f"{HUGGING_FACE_USER_NAME}/{merged_model_name}", use_auth_token=True)
#
# AttributeError: 'dict' object has no attribute 'push_to_hub'

# %%
from huggingface_hub import upload_file

# %%
upload_file(path_or_fileobj="./model.safetensors",
    path_in_repo="model.safetensors",
    repo_id="Andron00e/YetAnother_Open-Llama-3B-LoRA")
# Out:
# model.safetensors:   0%|          | 0.00/184 [00:00<?, ?B/s]
# 'https://huggingface.co/Andron00e/YetAnother_Open-Llama-3B-LoRA/blob/main/model.safetensors'

# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# Out:
# fatal: destination path 'lm-evaluation-harness' already exists and is not an empty directory.

# %%
# %cd lm-evaluation-harness
# Out:
# /content/lm-evaluation-harness

# %%
# !pip install -e ".[multilingual]"
# Out:
# Obtaining file:///content/lm-evaluation-harness
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.13.1)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (3.1.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.8.4)
# Requirement already satisfied: openai>=0.6.4 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.27.8)
# Requirement already satisfied: omegaconf>=2.2 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.3.0)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.5.0.dev0)
# Requirement already satisfied: pybind11>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.11.1)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (22.3.5)
# Requirement already satisfied: pytablewriter in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (1.0.0)
# Requirement already satisfied: rouge-score>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.1.2)
# Requirement already satisfied: sacrebleu==1.5.0 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (1.5.0)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (1.2.2)
# Requirement already satisfied: sqlitedict in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.1.0)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.0.1+cu118)
# Requirement already satisfied: tqdm-multiprocess in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.0.11)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (4.32.0.dev0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.21.0)
# Requirement already satisfied: accelerate>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.21.0)
# Requirement already satisfied: nagisa>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.2.8)
# Requirement already satisfied: jieba>=0.42.1 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.42.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu==1.5.0->lm-eval==0.3.0) (2.7.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (6.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (0.16.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from nagisa>=0.2.7->lm-eval==0.3.0) (1.16.0)
# Requirement already satisfied: DyNet38 in /usr/local/lib/python3.10/dist-packages (from nagisa>=0.2.7->lm-eval==0.3.0) (2.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.2->lm-eval==0.3.0) (4.9.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft>=0.2.0->lm-eval==0.3.0) (0.3.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm-eval==0.3.0) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm-eval==0.3.0) (3.8.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->lm-eval==0.3.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->lm-eval==0.3.0) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm-eval==0.3.0) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm-eval==0.3.0) (0.13.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm-eval==0.3.0) (23.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry->lm-eval==0.3.0) (67.7.2)
# Requirement already satisfied: DataProperty<2,>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm-eval==0.3.0) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm-eval==0.3.0) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm-eval==0.3.0) (3.1.0)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm-eval==0.3.0) (1.3.1)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm-eval==0.3.0) (0.1.3)
# Requirement already satisfied: typepy[datetime]<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm-eval==0.3.0) (1.3.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from tqdm-multiprocess->lm-eval==0.3.0) (0.4.6)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (1.3.1)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm-eval==0.3.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm-eval==0.3.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm-eval==0.3.0) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm-eval==0.3.0) (3.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter->lm-eval==0.3.0) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter->lm-eval==0.3.0) (2022.7.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from DyNet38->nagisa>=0.2.7->lm-eval==0.3.0) (0.29.36)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->lm-eval==0.3.0) (2.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm-eval==0.3.0) (8.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->lm-eval==0.3.0) (1.3.0)
# Installing collected packages: lm-eval
#   Attempting uninstall: lm-eval
#     Found existing installation: lm-eval 0.3.0
#     Uninstalling lm-eval-0.3.0:
#       Successfully uninstalled lm-eval-0.3.0
#   Running setup.py develop for lm-eval
# Successfully installed lm-eval-0.3.0

# %%
# !python main.py \
    --model hf-causal \
    --model_args pretrained=Andron00e/YetAnother_Open-Llama-3B-LoRA \
    --tasks hellaswag \
    --device cuda:0
# Out:
# 2023-07-21 11:54:39.467153: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
# Selected Tasks: ['hellaswag']
# Using device 'cuda:0'
# Traceback (most recent call last):
#   File "/content/lm-evaluation-harness/main.py", line 93, in <module>
#     main()
#   File "/content/lm-evaluation-harness/main.py", line 59, in main
#     results = evaluator.simple_evaluate(
#   File "/content/lm-evaluation-harness/lm_eval/utils.py", line 243, in _wrapper
#     return fn(*args, **kwargs)
#   File "/content/lm-evaluation-harness/lm_eval/evaluator.py", line 76, in simple_evaluate
#     lm = lm_eval.models.get_model(model).create_from_arg_string(
#   File "/content/lm-evaluation-harness/lm_eval/base.py", line 115, in create_from_arg_string
#     return cls(**args, **args2)
#   File "/content/lm-evaluation-harness/lm_eval/models/gpt2.py", line 85, in __init__
#     self.model = transformers.AutoModelForCausalLM.from_pretrained(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py", line 493, in from_pretrained
#     return model_class.from_pretrained(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 2629, in from_pretrained
#     state_dict = load_state_dict(resolved_archive_file)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 449, in load_state_dict
#     if metadata.get("format") not in ["pt", "tf", "flax"]:
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
# !git clone https://github.com/EleutherAI/lm-evaluation-harness
# %cd lm-evaluation-harness
# Out:
# fatal: destination path 'lm-evaluation-harness' already exists and is not an empty directory.
# /content/lm-evaluation-harness

# %%
# !pip install -e .

# %%
# !pip install -e ".[multilingual]"
# Out:
# Obtaining file:///content/lm-evaluation-harness
#   Preparing metadata (setup.py) ... done
# Collecting datasets>=2.0.0 (from lm-eval==0.3.0)
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 4.6 MB/s eta 0:00:00
# Collecting jsonlines (from lm-eval==0.3.0)
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.8.4)
# Collecting openai>=0.6.4 (from lm-eval==0.3.0)
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 5.1 MB/s eta 0:00:00
# Collecting omegaconf>=2.2 (from lm-eval==0.3.0)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.7 MB/s eta 0:00:00
# Collecting peft>=0.2.0 (from lm-eval==0.3.0)
#   Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 5.9 MB/s eta 0:00:00
# Collecting pybind11>=2.6.2 (from lm-eval==0.3.0)
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 6.1 MB/s eta 0:00:00
# Collecting pycountry (from lm-eval==0.3.0)
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 22.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytablewriter (from lm-eval==0.3.0)
#   Downloading pytablewriter-1.0.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 14.6 MB/s eta 0:00:00
# Collecting rouge-score>=0.0.4 (from lm-eval==0.3.0)
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu==1.5.0 (from lm-eval==0.3.0)
#   Downloading sacrebleu-1.5.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (1.2.2)
# Collecting sqlitedict (from lm-eval==0.3.0)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (2.0.1+cu118)
# Collecting tqdm-multiprocess (from lm-eval==0.3.0)
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Collecting transformers>=4.1 (from lm-eval==0.3.0)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 54.6 MB/s eta 0:00:00
# Collecting zstandard (from lm-eval==0.3.0)
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 67.9 MB/s eta 0:00:00
# Collecting accelerate>=0.17.1 (from lm-eval==0.3.0)
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 29.1 MB/s eta 0:00:00
# Collecting nagisa>=0.2.7 (from lm-eval==0.3.0)
#   Downloading nagisa-0.2.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 56.1 MB/s eta 0:00:00
# Requirement already satisfied: jieba>=0.42.1 in /usr/local/lib/python3.10/dist-packages (from lm-eval==0.3.0) (0.42.1)
# Collecting portalocker (from sacrebleu==1.5.0->lm-eval==0.3.0)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.17.1->lm-eval==0.3.0) (6.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets>=2.0.0->lm-eval==0.3.0)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (4.65.0)
# Collecting xxhash (from datasets>=2.0.0->lm-eval==0.3.0)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 26.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.0.0->lm-eval==0.3.0)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0) (3.8.4)
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets>=2.0.0->lm-eval==0.3.0)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from nagisa>=0.2.7->lm-eval==0.3.0) (1.16.0)
# Collecting DyNet38 (from nagisa>=0.2.7->lm-eval==0.3.0)
#   Downloading dyNET38-2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 53.3 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.2->lm-eval==0.3.0)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting safetensors (from peft>=0.2.0->lm-eval==0.3.0)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm-eval==0.3.0) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm-eval==0.3.0) (3.8.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->lm-eval==0.3.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->lm-eval==0.3.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->lm-eval==0.3.0) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm-eval==0.3.0) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.1->lm-eval==0.3.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm-eval==0.3.0) (23.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry->lm-eval==0.3.0) (67.7.2)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter->lm-eval==0.3.0)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm-eval==0.3.0)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm-eval==0.3.0)
#   Downloading pathvalidate-3.1.0-py3-none-any.whl (21 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm-eval==0.3.0)
#   Downloading tabledata-1.3.1-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm-eval==0.3.0)
#   Downloading tcolorpy-0.1.3-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter->lm-eval==0.3.0)
#   Downloading typepy-1.3.1-py3-none-any.whl (31 kB)
# Collecting colorama (from tqdm-multiprocess->lm-eval==0.3.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->lm-eval==0.3.0) (1.3.1)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm-eval==0.3.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm-eval==0.3.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm-eval==0.3.0) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.0.0->lm-eval==0.3.0) (3.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter->lm-eval==0.3.0) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter->lm-eval==0.3.0) (2022.7.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from DyNet38->nagisa>=0.2.7->lm-eval==0.3.0) (0.29.36)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->lm-eval==0.3.0) (2.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm-eval==0.3.0) (8.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->lm-eval==0.3.0) (1.3.0)
# Building wheels for collected packages: antlr4-python3-runtime, rouge-score, pycountry, sqlitedict
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=83ae7546b0c0d821845e9d15cbf43222e6e06ad8b52135e6cdf7d5f205a0b9f9
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=3eb21d5bf3658287c396c7e486866c04073cbcc695c8795dcb98bd1987a2de54
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681832 sha256=c070eac9dd21e95ec453cd9616237067e2738b49f453aedd18936ee4d154a7d6
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=71ddf22c506f9d08b55d4001f736bddae8a0637820738b3afaad302b0cb52a2e
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built antlr4-python3-runtime rouge-score pycountry sqlitedict
# Installing collected packages: tokenizers, sqlitedict, safetensors, antlr4-python3-runtime, zstandard, xxhash, tcolorpy, pycountry, pybind11, portalocker, pathvalidate, omegaconf, mbstrdecoder, jsonlines, DyNet38, dill, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, nagisa, multiprocess, huggingface-hub, transformers, openai, datasets, DataProperty, tabledata, pytablewriter, accelerate, peft, lm-eval
#   Running setup.py develop for lm-eval
# Successfully installed DataProperty-1.0.1 DyNet38-2.1 accelerate-0.21.0 antlr4-python3-runtime-4.9.3 colorama-0.4.6 datasets-2.13.1 dill-0.3.6 huggingface-hub-0.16.4 jsonlines-3.1.0 lm-eval-0.3.0 mbstrdecoder-1.1.3 multiprocess-0.70.14 nagisa-0.2.8 omegaconf-2.3.0 openai-0.27.8 pathvalidate-3.1.0 peft-0.4.0 portalocker-2.7.0 pybind11-2.11.1 pycountry-22.3.5 pytablewriter-1.0.0 rouge-score-0.1.2 sacrebleu-1.5.0 safetensors-0.3.1 sqlitedict-2.1.0 tabledata-1.3.1 tcolorpy-0.1.3 tokenizers-0.13.3 tqdm-multiprocess-0.0.11 transformers-4.31.0 typepy-1.3.1 xxhash-3.2.0 zstandard-0.21.0

# %%
# !python main.py \
    --model hf-causal \
    --model_args pretrained=Andron00e/YetAnother_Open-Llama-3B-LoRA \
    --tasks hellaswag \
    --device cuda:0
# Out:
# 2023-07-21 12:18:29.757618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.
# Selected Tasks: ['hellaswag']
# Using device 'cuda:0'
# Downloading (…)lve/main/config.json: 100% 635/635 [00:00<00:00, 3.65MB/s]
# Downloading model.safetensors: 100% 6.85G/6.85G [01:42<00:00, 66.7MB/s]
# Downloading (…)neration_config.json: 100% 137/137 [00:00<00:00, 851kB/s]
# Downloading (…)okenizer_config.json: 100% 718/718 [00:00<00:00, 4.83MB/s]
# Downloading tokenizer.model: 100% 534k/534k [00:00<00:00, 11.0MB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.98M/1.98M [00:00<00:00, 26.1MB/s]
# Downloading (…)cial_tokens_map.json: 100% 411/411 [00:00<00:00, 2.75MB/s]
# Downloading builder script: 100% 4.36k/4.36k [00:00<00:00, 21.4MB/s]
# Downloading metadata: 100% 2.53k/2.53k [00:00<00:00, 19.1MB/s]
# Downloading readme: 100% 6.85k/6.85k [00:00<00:00, 34.2MB/s]
# Downloading and preparing dataset hellaswag/default to /root/.cache/huggingface/datasets/hellaswag/default/0.1.0/512a66dd8b1b1643ab4a48aa4f150d04c91680da6a4096498a5e5f799623d5ae...
# Downloading data files:   0% 0/3 [00:00<?, ?it/s]
# Downloading data:   0% 0.00/12.1M [00:00<?, ?B/s]
# Downloading data:  31% 3.73M/12.1M [00:00<00:00, 37.3MB/s]
# Downloading data: 12.3MB [00:00, 65.7MB/s]
# Downloading data: 18.9MB [00:00, 65.8MB/s]
# Downloading data: 26.5MB [00:00, 69.8MB/s]
# Downloading data: 33.9MB [00:00, 71.3MB/s]
# Downloading data: 47.5MB [00:00, 68.0MB/s]
# Downloading data files:  33% 1/3 [00:04<00:08,  4.43s/it]
# Downloading data:   0% 0.00/3.04M [00:00<?, ?B/s]
# Downloading data:  97% 2.95M/3.04M [00:00<00:00, 29.5MB/s]
# Downloading data: 11.8MB [00:00, 46.9MB/s]
# Downloading data files:  67% 2/3 [00:06<00:02,  2.84s/it]
# Downloading data:   0% 0.00/3.14M [00:00<?, ?B/s]
# Downloading data: 3.30MB [00:00, 32.9MB/s]
# Downloading data: 12.2MB [00:00, 50.0MB/s]
# Downloading data files: 100% 3/3 [00:07<00:00,  2.53s/it]
# Extracting data files: 100% 3/3 [00:00<00:00, 1458.55it/s]
# Dataset hellaswag downloaded and prepared to /root/.cache/huggingface/datasets/hellaswag/default/0.1.0/512a66dd8b1b1643ab4a48aa4f150d04c91680da6a4096498a5e5f799623d5ae. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 139.77it/s]
# Task: hellaswag; number of docs: 10042
# Task: hellaswag; document 0; context prompt (starting on next line):
# Personal Care and Style: How to increase breast size with a bra. Check your bra size. Wearing a bra that is too big will not make your breasts look larger. That is why it is important to wear the right size bra for you.
# (end of prompt on previous line)
# Requests: [Req_loglikelihood('Personal Care and Style: How to increase breast size with a bra. Check your bra size. Wearing a bra that is too big will not make your breasts look larger. That is why it is important to wear the right size bra for you.', ' You can visit a lingerie shop and have them measure you to help you fit a bra to your size, or measure yourself before you shop for a new bra to ensure that you get a good fit. Use a flexible tape measure, like one found in a sewing kit.')[0]
# , Req_loglikelihood('Personal Care and Style: How to increase breast size with a bra. Check your bra size. Wearing a bra that is too big will not make your breasts look larger. That is why it is important to wear the right size bra for you.', ' This is why it is important to keep your breasts under protection when in the shower and only wear bras that are larger than your breast size. If you are not wearing a bra, try wearing something that is a little bigger.')[0]
# , Req_loglikelihood('Personal Care and Style: How to increase breast size with a bra. Check your bra size. Wearing a bra that is too big will not make your breasts look larger. That is why it is important to wear the right size bra for you.', ' For a girl, a bra with a support strap will be easier for her, because most women are unable to pull through bra straps and bras that are too small will not be able to support breasts from side-to-side. Many bras have even been created that cover the breast side, and can be sent to other women in the world to make them look bigger.')[0]
# , Req_loglikelihood('Personal Care and Style: How to increase breast size with a bra. Check your bra size. Wearing a bra that is too big will not make your breasts look larger. That is why it is important to wear the right size bra for you.', ' Choose a color that is flattering to your breast type and specific event, in addition to those that make you uncomfortable. Look for sports bras made from natural material, such as spandex or lycra, as this is a more breathable bra.')[0]
# ]
# Running loglikelihood requests
# 100% 40145/40145 [1:32:39<00:00,  7.22it/s]
# {
#   "results": {
#     "hellaswag": {
#       "acc": 0.46176060545708025,
#       "acc_stderr": 0.004975167382061836,
#       "acc_norm": 0.6018721370244972,
#       "acc_norm_stderr": 0.00488511646555027
#     }
#   },
#   "versions": {
#     "hellaswag": 0
#   },
#   "config": {
#     "model": "hf-causal",
#     "model_args": "pretrained=Andron00e/YetAnother_Open-Llama-3B-LoRA",
#     "num_fewshot": 0,
#     "batch_size": null,
#     "batch_sizes": [],
#     "device": "cuda:0",
#     "no_cache": false,
#     "limit": null,
#     "bootstrap_iters": 100000,
#     "description_dict": {}
#   }
# }
# hf-causal (pretrained=Andron00e/YetAnother_Open-Llama-3B-LoRA), limit: None, provide_description: False, num_fewshot: 0, batch_size: None
# |  Task   |Version| Metric |Value |   |Stderr|
# |---------|------:|--------|-----:|---|-----:|
# |hellaswag|      0|acc     |0.4618|±  |0.0050|
# |         |       |acc_norm|0.6019|±  |0.0049|
